# %%
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# %%
# !wget -q https://raw.githubusercontent.com/cseas/style-transfer/master/style_transfer.py
# !wget -q https://raw.githubusercontent.com/cseas/style-transfer/master/stylize.py
# !wget -q https://raw.githubusercontent.com/cseas/style-transfer/master/vgg.py
# !wget -q https://raw.githubusercontent.com/myelin-foundry/challenge/master/japanese_garden.jpg
# !wget -q https://raw.githubusercontent.com/myelin-foundry/challenge/master/picasso_selfportrait.jpg

# %%
# Download pre-trained VGG network
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Out:
# --2019-04-14 08:26:34--  http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M) [text/plain]
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  67.5MB/s    in 8.0s
#
# 2019-04-14 08:26:42 (63.7 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]

# %%
# !ls
# !rm *.*
# Out:
# imagenet-vgg-verydeep-19.mat  __pycache__	 stylize.py
# japanese_garden.jpg	      sample_data	 vgg.py
# picasso_selfportrait.jpg      style_transfer.py

# %%
# !python style_transfer.py --content japanese_garden.jpg --styles picasso_selfportrait.jpg --output output.jpg
# Out:
# tcmalloc: large alloc 1101725696 bytes == 0x4e0ce000 @  0x7fd28629a1e7 0x7fd264ab94c5 0x7fd264c0b1ee 0x7fd264c0d5be 0x7fd264c1abec 0x7fd25d68db7d 0x7fd25d68e11f 0x7fd25d705ef7 0x7fd25d702b28 0x7fd284b7c57f 0x7fd285c5e6db 0x7fd285f9788f
# tcmalloc: large alloc 2718023680 bytes == 0x80286000 @  0x7fd28629a1e7 0x7fd264ab94c5 0x7fd264c0b1ee 0x7fd264c0d5be 0x7fd264c1abec 0x7fd25d68db7d 0x7fd25d68e11f 0x7fd25d705ef7 0x7fd25d702b28 0x7fd284b7c57f 0x7fd285c5e6db 0x7fd285f9788f
# tcmalloc: large alloc 2718023680 bytes == 0x7bac0000 @  0x7fd28629a1e7 0x7fd264ab94c5 0x7fd264c0b1ee 0x7fd264c0d5be 0x7fd264c1abec 0x7fd25d68db7d 0x7fd25d68e11f 0x7fd25d705ef7 0x7fd25d702b28 0x7fd284b7c57f 0x7fd285c5e6db 0x7fd285f9788f
# tcmalloc: large alloc 2718023680 bytes == 0x74ed2000 @  0x7fd28629a1e7 0x7fd264ab94c5 0x7fd264c0b1ee 0x7fd264c0d5be 0x7fd264c1abec 0x7fd25d68db7d 0x7fd25d68e11f 0x7fd25d705ef7 0x7fd25d702b28 0x7fd284b7c57f 0x7fd285c5e6db 0x7fd285f9788f
# ...

# %%
from PIL import Image
import IPython.display

im = Image.open('japanese_garden.jpg')
IPython.display.display(im)

im = Image.open('picasso_selfportrait.jpg')
IPython.display.display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x498 at 0x7FD201D3C588>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=468x600 at 0x7FD201D3C7B8>

# %%
im = Image.open('output.jpg')
IPython.display.display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x498 at 0x7FD201D3C2B0>
